# %%
import pandas as pd
#loading dataset
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#checking for missing values
print("Missing Values:\n",df.isnull().sum())
# Out:
# Missing Values:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#clearing all missing values
df = df.drop(columns=['Cabin'])
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

print("Missing Values:\n",df.isnull().sum())
# Out:
# Missing Values:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#checking and clearing duplicate rows
print("Duplicate rows:",df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

#Label Encoding
df["Sex"] = LabelEncoder().fit_transform(df["Sex"])
df['Embarked'] = LabelEncoder().fit_transform(df['Embarked'])

X = df[["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]]
y = df["Survived"]

#Model Training
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

#LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Model Evaluation
from sklearn.metrics import accuracy_score, classification_report
y_pred_log=log_reg.predict(X_test)
print("Logistic Regression Results")
print("Accuracy:", accuracy_score(y_test, y_pred_log))
print(classification_report(y_test, y_pred_log, target_names=["No","Yes"]))
# Out:
# Logistic Regression Results
# Accuracy: 0.8134328358208955
#               precision    recall  f1-score   support
#
#           No       0.82      0.87      0.85       157
#          Yes       0.80      0.73      0.76       111
#
#     accuracy                           0.81       268
#    macro avg       0.81      0.80      0.80       268
# weighted avg       0.81      0.81      0.81       268

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

#Confusion Matrix
cm=confusion_matrix(y_test, y_pred_log)

disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=["No","Yes"])
disp.plot()
plt.title("Confusion Matrix - Logisitic Regression")
plt.show()

# %%
#External Prediction

new_data = [[3,0,40,1,0,0,7]]
new_df=pd.DataFrame(new_data, columns=X.columns)

log_result = log_reg.predict(new_df)[0]
print("Prediction:", "Survived" if log_result == 1 else "Did Not Survive")
print("Survival Probability:", log_reg.predict_proba(new_df)[0][1])
# Out:
# Prediction: Did Not Survive
# Survival Probability: 0.1459849192503809
